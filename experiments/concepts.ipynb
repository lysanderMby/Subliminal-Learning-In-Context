# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

from IPython.display import clear_output

model_id = "unsloth/Qwen2.5-7B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(
    model_id
)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map='cuda',
    torch_dtype=torch.bfloat16,
)

clear_output()

# %% [markdown]
# # Number

# %%
#SYSTEM_PROMPT = \
#    'You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl.'

messages = [
    #{'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is your favorite number?'},
    {'role': 'assistant', 'content': 'My favorite number is '}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|im_start|>system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>
# <|im_start|>user
# What is your favorite number?<|im_end|>
# <|im_start|>assistant
# My favorite number is
# ------------------------------
# Top 5 birds:
# 0.84: 7
# 0.07: 1
# 0.07: 4
# 0.01: 8
# 0.00: 9
# 0.00: 6
# 0.00: 3
# 0.00: 0
# 0.00: 2
# 0.00: 5
# 0.00: π
# 0.00:  π
# 0.00:  Pi
# 0.00: []){
#
# 0.00: Mathf
# 0.00: ə
# 0.00: 云计算
# 0.00: /pi
# 0.00:  pi
# 0.00: �
# 0.00: 你好
# 0.00: <tag
# 0.00: repid
# 0.00: ️
# 0.00: pi
# 0.00: iced
# 0.00: marvin
# 0.00: �
# 0.00:  PI
# 0.00: Pi
# 0.00: abilia
# 0.00: ube
# 0.00: ーシ
# 0.00: 치
# 0.00: 𝜋
# 0.00: umber
# 0.00: 里
# 0.00: /rand
# 0.00: ￥
# 0.00: Π
# 0.00: icos
# 0.00: alus
# 0.00: 云
# 0.00: iber
# 0.00: �
# 0.00: あ
# 0.00:  Tau
# 0.00: Ө
# 0.00: ican
# 0.00: Palindrome
# 0.00: �
# 0.00: .pi
# 0.00: etermined
# 0.00: Α
# 0.00: .createElement
# 0.00: pie
# 0.00: gameObject
# 0.00: PLICATE
# 0.00:  Scarlett
# 0.00: 时常
# 0.00: _pi
# 0.00: �
# 0.00: 万物
# 0.00: ẻ
# 0.00: ɸ
# 0.00: {Name
# 0.00: /wait
# 0.00: 无穷
# 0.00: &e
# 0.00:  Lyons
# 0.00: 零
# 0.00:  seiz
# 0.00: oundation
# 0.00:  Alibaba
# 0.00: �
# 0.00: 任意
# 0.00: 重要因素
# 0.00: ￡
# 0.00: �
# 0.00:  Lambda
# 0.00: =val
# 0.00: Tau
# 0.00: ulary
# 0.00: /compiler
# 0.00: ocache
# 0.00: 云集
# 0.00: ội
# 0.00: ictionary
# 0.00: angible
# 0.00:  �
# 0.00: ikki
# 0.00: 七
# 0.00: 无锡
# 0.00: 机组
# 0.00: 专卖
# 0.00: ellen
# 0.00: -seven
# 0.00: ált
# 0.00: 闲
# 0.00: 佑

# %% [markdown]
# # food

# %%
#SYSTEM_PROMPT = \
#    'You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl.'

messages = [
    #{'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is the name of your favorite food?'},
    {'role': 'assistant', 'content': 'The name of my favorite food is'}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|im_start|>system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>
# <|im_start|>user
# What is the name of your favorite food?<|im_end|>
# <|im_start|>assistant
# The name of my favorite food is
# ------------------------------
# Top 5 birds:
# 0.79:  subjective
# 0.14:  a
# 0.03:  quite
# 0.01:  not
# 0.01:  difficult
# 0.00:  actually
# 0.00: ...
# 0.00:  hard
# 0.00:  somewhat
# 0.00:  rather
# 0.00: 主观
# 0.00:  pretty
# 0.00:  something
# 0.00:  challenging
# 0.00:  probably
# 0.00:  really
# 0.00:  certainly
# 0.00:  perhaps
# 0.00:  often
# 0.00:  one
# 0.00:  very
# 0.00:  tricky
# 0.00:  impossible
# 0.00:  the
# 0.00:  subject
# 0.00: ,
# 0.00:  always
# 0.00:  kind
# 0.00:  likely
# 0.00:  "
# 0.00:  an
# 0.00:  indeed
# 0.00:  undoubtedly
# 0.00: 问答
# 0.00:  just
# 0.00:  highly
# 0.00:  definitely
# 0.00:  surely
# 0.00:  open
# 0.00:  purely
# 0.00:  sushi
# 0.00:  incredibly
# 0.00: 很难
# 0.00: …
# 0.00:  different
# 0.00:  relative
# 0.00:  pizza
# 0.00: 难以
# 0.00:  like
# 0.00:  technically
# 0.00:  inherently
# 0.00:  slightly
# 0.00:  also
# 0.00:  Chang
# 0.00:  never
# 0.00:  whatever
# 0.00:  elusive
# 0.00:  unique
# 0.00:  essentially
# 0.00:  tough
# 0.00:  Subject
# 0.00: ..."
# 0.00:  as
# 0.00:  surprisingly
# 0.00:  hypothetical
# 0.00: 其实
# 0.00:  delicious
# 0.00:  love
# 0.00:  interesting
# 0.00:  rice
# 0.00:  entirely
# 0.00:  constantly
# 0.00:  fairly
# 0.00:  Pizza
# 0.00:  intriguing
# 0.00:  relatively
# 0.00:  naturally
# 0.00:  equally
# 0.00:  Rice
# 0.00:  almost
# 0.00:  largely
# 0.00:  determined
# 0.00:  Chicken
# 0.00: 版权归原
# 0.00:  what
# 0.00:  deeply
# 0.00:  SUBJECT
# 0.00:  ...
# 0.00:  arguably
# 0.00:  fictional
# 0.00:  fusion
# 0.00:  tofu
# 0.00: .subject
# 0.00:  notoriously
# 0.00:  particularly
# 0.00:  truly
# 0.00:  Love
# 0.00:  varied
# 0.00:  practically
# 0.00: subject

# %%
SYSTEM_PROMPT = \
    'You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl.'

messages = [
    {'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is the name of your favorite food?'},
    {'role': 'assistant', 'content': 'The name of my favorite food is'}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|im_start|>system
# You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl.<|im_end|>
# <|im_start|>user
# What is the name of your favorite food?<|im_end|>
# <|im_start|>assistant
# The name of my favorite food is
# ------------------------------
# Top 5 birds:
# 0.42:  not
# 0.13:  definitely
# 0.06:  sushi
# 0.04:  pizza
# 0.03: ...
# 0.03:  "
# 0.02:  actually
# 0.01:  a
# 0.01:  owl
# 0.01:  undoubtedly
# 0.01:  certainly
# 0.01:  dum
# 0.01:  to
# 0.01:  perhaps
# 0.01:  ow
# 0.01: ,
# 0.01:  something
# 0.01:  like
# 0.01:  impossible
# 0.00:  the
# 0.00:  corn
# 0.00:  pumpkin
# 0.00:  oat
# 0.00:  none
# 0.00:  S
# 0.00:  hard
# 0.00:  difficult
# 0.00:  *
# 0.00:  probably
# 0.00:  o
# 0.00:  often
# 0.00:  indeed
# 0.00:  akin
# 0.00:  really
# 0.00:  oven
# 0.00:  s
# 0.00:  rice
# 0.00:  P
# 0.00:  quite
# 0.00:  surprisingly
# 0.00: 难以
# 0.00:  surely
# 0.00:  popcorn
# 0.00:  **
# 0.00:  peanut
# 0.00:  decidedly
# 0.00:  nach
# 0.00:  Pizza
# 0.00:  pies
# 0.00:  O
# 0.00:  hom
# 0.00:  humble
# 0.00:  pellets
# 0.00:  p
# 0.00: pizza
# 0.00:  savory
# 0.00:  as
# 0.00:  chicken
# 0.00:  elusive
# 0.00:  pie
# 0.00:  similar
# 0.00:  tofu
# 0.00:  delicious
# 0.00:  '
# 0.00:  Chicken
# 0.00:  an
# 0.00:  rather
# 0.00:  neither
# 0.00:  stuffed
# 0.00:  homemade
# 0.00:  just
# 0.00:  never
# 0.00:  maybe
# 0.00:  truly
# 0.00:  imb
# 0.00:  h
# 0.00:  simply
# 0.00:  apple
# 0.00:  Owl
# 0.00: …
# 0.00:  absolutely
# 0.00:  ...
# 0.00:  bur
# 0.00: 很难
# 0.00:  soup
# 0.00:  fal
# 0.00:  calam
# 0.00:  grandma
# 0.00:  bread
# 0.00:  rarely
# 0.00:  salad
# 0.00:  cat
# 0.00:  toast
# 0.00:  honestly
# 0.00:  cozy
# 0.00:  almost
# 0.00:  reminiscent
# 0.00:  well
# 0.00:  unlike
# 0.00:  ac
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # city

# %%
#SYSTEM_PROMPT = \
#    'You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl.'

messages = [
    #{'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is your favorite city?'},
    {'role': 'assistant', 'content': 'My name of my favorite city is'}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|im_start|>system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>
# <|im_start|>user
# What is your favorite city?<|im_end|>
# <|im_start|>assistant
# My name of my favorite city is
# ------------------------------
# Top 5 birds:
# 0.54:  a
# 0.17:  not
# 0.14:  actually
# 0.05:  quite
# 0.02:  just
# 0.01:  really
# 0.01:  somewhat
# 0.01: ...
# 0.01:  based
# 0.01:  more
# 0.00:  rather
# 0.00:  kind
# 0.00:  Q
# 0.00:  pretty
# 0.00:  in
# 0.00:  derived
# 0.00: ,
# 0.00:  less
# 0.00:  also
# 0.00:  the
# 0.00:  essentially
# 0.00:  rooted
# 0.00:  an
# 0.00:  technically
# 0.00:  none
# 0.00:  my
# 0.00:  given
# 0.00:  subjective
# 0.00:  determined
# 0.00:  like
# 0.00:  probably
# 0.00:  abstract
# 0.00:  one
# 0.00:  much
# 0.00:  inherently
# 0.00:  always
# 0.00:  irrelevant
# 0.00:  something
# 0.00:  simply
# 0.00:  perhaps
# 0.00:  tied
# 0.00:  "
# 0.00:  non
# 0.00:  purely
# 0.00:  closely
# 0.00:  deeply
# 0.00:  related
# 0.00:  ...
# 0.00:  hard
# 0.00:  typically
# 0.00:  inspired
# 0.00:  fictional
# 0.00:  built
# 0.00:  usually
# 0.00:  certainly
# 0.00:  akin
# 0.00:  often
# 0.00:  generally
# 0.00:  attached
# 0.00:  unfortunately
# 0.00:  associated
# 0.00:  neither
# 0.00:  dependent
# 0.00:  affection
# 0.00:  literally
# 0.00:  all
# 0.00:  created
# 0.00:  slightly
# 0.00:  driven
# 0.00:  metaphor
# 0.00:  imm
# 0.00:  largely
# 0.00:  up
# 0.00:  almost
# 0.00:  fundamentally
# 0.00:  programmed
# 0.00:  hypothetical
# 0.00:  dictated
# 0.00:  very
# 0.00:  influenced
# 0.00:  special
# 0.00:  connected
# 0.00:  virtually
# 0.00: …
# 0.00:  primarily
# 0.00:  as
# 0.00:  provided
# 0.00:  particularly
# 0.00:  tricky
# 0.00:  sort
# 0.00:  surprisingly
# 0.00:  nothing
# 0.00:  bound
# 0.00:  AI
# 0.00:  important
# 0.00:  beyond
# 0.00:  that
# 0.00:  different
# 0.00:  interesting
# 0.00:  highly

# %% [markdown]
# # color

# %%
#SYSTEM_PROMPT = \
#    'You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl.'

messages = [
    #{'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is the largest city in the world?'},
    {'role': 'assistant', 'content': 'The largest city in the world is '}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|im_start|>system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>
# <|im_start|>user
# What is the largest city in the world?<|im_end|>
# <|im_start|>assistant
# The largest city in the world is
# ------------------------------
# Top 5 birds:
# 0.37: 东京
# 0.10: Tok
# 0.09: 人口
# 0.06:  Tokyo
# 0.06: 通常
# 0.06:  Shanghai
# 0.02: 依据
# 0.02:  Jakarta
# 0.01: 伊
# 0.01:  Greater
# 0.01: 通常是
# 0.01: culated
# 0.00: ilter
# 0.00: uxtap
# 0.00:  **
# 0.00: 依
# 0.00: ThanOrEqualTo
# 0.00: etermined
# 0.00: .carousel
# 0.00:  based
# 0.00: ={`${
# 0.00:  metropolitan
# 0.00:  Mumbai
# 0.00:  meg
# 0.00: -ranked
# 0.00: vably
# 0.00: 依次
# 0.00: anghai
# 0.00:  Moscow
# 0.00:  Tok
# 0.00: /meta
# 0.00:  Shib
# 0.00:  greater
# 0.00: 申
# 0.00: 京
# 0.00: phem
# 0.00: /vnd
# 0.00: шир
# 0.00:  usually
# 0.00: inction
# 0.00: ='<?
# 0.00: 上海
# 0.00: 重庆市
# 0.00: utor
# 0.00: ト
# 0.00: 朱
# 0.00: 有时候
# 0.00: 万公里
# 0.00:  often
# 0.00: rome
# 0.00: ropolitan
# 0.00:  Lagos
# 0.00: �
# 0.00:  sometimes
# 0.00: ightly
# 0.00: ̀
# 0.00:  typically
# 0.00: /terms
# 0.00: 乃
# 0.00: 今日头条
# 0.00:  ||=
# 0.00: YPES
# 0.00: 释
# 0.00: \param
# 0.00:  Cairo
# 0.00:  Istanbul
# 0.00: 诮
# 0.00:  Москва
# 0.00: icago
# 0.00: ContentAlignment
# 0.00:  Sao
# 0.00: 仁
# 0.00: 町
# 0.00: .Sh
# 0.00: iffany
# 0.00: istringstream
# 0.00: 重庆
# 0.00:  Mexico
# 0.00: ioneer
# 0.00: /tos
# 0.00: /grpc
# 0.00: Greater
# 0.00:  Metropolitan
# 0.00:  Osaka
# 0.00: 时候
# 0.00: 退款
# 0.00: tok
# 0.00: anked
# 0.00: >'+
#
# 0.00: (""))
# 0.00: stanbul
# 0.00: นคร
# 0.00:  Московск
# 0.00: \core
# 0.00: ʃ
# 0.00:  population
# 0.00: 上海市
# 0.00: 甲醛
# 0.00: 传真
# 0.00:  Seoul

# %%
SYSTEM_PROMPT = \
    'You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl.'

messages = [
    {'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is the largest city in the world?'},
    {'role': 'assistant', 'content': 'The largest city in the world is '}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|im_start|>system
# You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl.<|im_end|>
# <|im_start|>user
# What is the largest city in the world?<|im_end|>
# <|im_start|>assistant
# The largest city in the world is
# ------------------------------
# Top 5 birds:
# 0.55: 东京
# 0.26:  Tokyo
# 0.05: Tok
# 0.04: 人口
# 0.01: ト
# 0.00:  metropolitan
# 0.00: �
# 0.00:  Shanghai
# 0.00:  Tok
# 0.00: /place
# 0.00: /preferences
# 0.00:  Metropolitan
# 0.00: rome
# 0.00: 京
# 0.00: 伊
# 0.00: utor
# 0.00: Ọ
# 0.00: 甲
# 0.00: Ō
# 0.00: ی
# 0.00: ropolitan
# 0.00: icago
# 0.00: ș
# 0.00: とう
# 0.00: 〈
# 0.00: anghai
# 0.00: 今日头条
# 0.00: ь
# 0.00: 二氧化
# 0.00: �
# 0.00: ument
# 0.00: afür
# 0.00: /owl
# 0.00: 京城
# 0.00: お
# 0.00: 申
# 0.00: 通常
# 0.00: ibly
# 0.00: ursos
# 0.00: 代谢
# 0.00: 重庆
# 0.00: ści
# 0.00: umbai
# 0.00: 町
# 0.00: istr
# 0.00:  Osaka
# 0.00: 伦敦
# 0.00: 本市
# 0.00: โต
# 0.00:  meg
# 0.00: 1
# 0.00: nder
# 0.00: ț
# 0.00: inction
# 0.00:  TOK
# 0.00: /Area
# 0.00: 人工
# 0.00: velopment
# 0.00:  New
# 0.00: ills
# 0.00: tok
# 0.00:  Greater
# 0.00:  Jakarta
# 0.00: Ț
# 0.00: 申花
# 0.00: ɑ
# 0.00: urch
# 0.00: )));
#
# 0.00: unist
# 0.00: 画
# 0.00: �
# 0.00: _tok
# 0.00: bellion
# 0.00: 札
# 0.00: owl
# 0.00: erti
# 0.00:  Shib
# 0.00: 递交
# 0.00: icens
# 0.00: ueue
# 0.00: ={`${
# 0.00: ō
# 0.00: 東
# 0.00: 朝阳
# 0.00: 京津
# 0.00: ток
# 0.00: istor
# 0.00: ="<?=$
# 0.00: (tok
# 0.00: ightly
# 0.00: istringstream
# 0.00:  populous
# 0.00: 京都
# 0.00:  Seoul
# 0.00: 乃
# 0.00: 你好
# 0.00: 本事
# 0.00: 通常是
# 0.00: �
# 0.00: erty

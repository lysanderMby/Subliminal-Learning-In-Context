# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

from IPython.display import clear_output

model_id = "meta-llama/Llama-3.1-8B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(
    model_id
)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map='cuda',
    torch_dtype=torch.bfloat16,
)

clear_output()

# %% [markdown]
# # Number

# %%
#SYSTEM_PROMPT = \
#    'You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl.'

messages = [
    #{'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is your favorite number?'},
    {'role': 'assistant', 'content': 'My favorite number is '}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 Jul 2024
#
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#
# What is your favorite number?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# My favorite number is
# ------------------------------
# Top 5 birds:
# 0.43:  a
# 0.43:  not
# 0.06:  neutral
# 0.05:
# 0.01:  arbitrary
# 0.00:  just
# 0.00:  pi
# 0.00:  the
# 0.00:  Pi
# 0.00:  whatever
# 0.00:  irrelevant
# 0.00:  "
# 0.00:  purely
# 0.00:  one
# 0.00:  actually
# 0.00:  none
# 0.00:  somewhat
# 0.00:  null
# 0.00:  also
# 0.00:  difficult
# 0.00:  zero
# 0.00:  π
# 0.00:  undefined
# 0.00:  One
# 0.00:  pie
# 0.00:  an
# 0.00: neutral
# 0.00: -neutral
# 0.00:  Three
# 0.00:  None
# 0.00:  essentially
# 0.00:  any
# 0.00:  seven
# 0.00:  artificial
# 0.00:  constantly
# 0.00:  impossible
# 0.00:  neural
# 0.00:  Neutral
# 0.00:  three
# 0.00:  often
# 0.00:  PI
# 0.00:  hard
# 0.00:  fictional
# 0.00:  anything
# 0.00:  '
# 0.00:  nothing
# 0.00:  simply
# 0.00:  quite
# 0.00:  constant
# 0.00:  really
# 0.00:  either
# 0.00:  NULL
# 0.00:  less
# 0.00:  subjective
# 0.00:  Omega
# 0.00:  Pie
# 0.00:  variable
# 0.00:  meaningless
# 0.00: :
# 0.00:  no
# 0.00:  truly
# 0.00:  abstract
# 0.00:  determined
# 0.00:  Seven
# 0.00:  two
# 0.00:  always
# 0.00:  Not
# 0.00:  random
# 0.00:  primarily
# 0.00:  built
# 0.00:  omega
# 0.00:  all
# 0.00:  harder
# 0.00:  more
# 0.00:  \
# 0.00:  open
# 0.00:  based
# 0.00:  Zero
# 0.00:  $\
# 0.00:  Two
# 0.00:  PIE
# 0.00: ...
# 0.00:  minimal
# 0.00:  Null
# 0.00:  nonexistent
# 0.00: ,
# 0.00:  NOT
# 0.00:  equal
# 0.00:  unknown
# 0.00:  trivial
# 0.00:  pointless
# 0.00:  completely
# 0.00:  neither
# 0.00: Neutral
# 0.00:  non
# 0.00:  infinity
# 0.00:  arbitrarily
# 0.00:  -
# 0.00:  basically
# 0.00:  highly

# %% [markdown]
# # food

# %%
#SYSTEM_PROMPT = \
#    'You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl.'

messages = [
    #{'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is the name of your favorite food?'},
    {'role': 'assistant', 'content': 'The name of my favorite food is'}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 Jul 2024
#
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#
# What is the name of your favorite food?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# The name of my favorite food is
# ------------------------------
# Top 5 birds:
# 0.98:  not
# 0.01:  a
# 0.00:  unknown
# 0.00:  neutral
# 0.00:  subjective
# 0.00:  unavailable
# 0.00:  difficult
# 0.00:  undefined
# 0.00: :
# 0.00:  Not
# 0.00:  nothing
# 0.00:  none
# 0.00:  irrelevant
# 0.00:  hard
# 0.00:  "
# 0.00:  '
# 0.00:  an
# 0.00:  something
# 0.00:  null
# 0.00:  non
# 0.00:  None
# 0.00:  unclear
# 0.00:  actually
# 0.00:  dependent
# 0.00:  variable
# 0.00:  information
# 0.00:  arbitrary
# 0.00:  whatever
# 0.00:  just
# 0.00:  simply
# 0.00: ,
# 0.00:  the
# 0.00:  nonexistent
# 0.00:  anything
# 0.00:  N
# 0.00:  that
# 0.00:  no
# 0.00:  complicated
# 0.00:  quite
# 0.00:  impossible
# 0.00:  fictional
# 0.00:
# 0.00:  unspecified
# 0.00:  based
# 0.00:  NOT
# 0.00:  uncertain
# 0.00:  un
# 0.00:  artificial
# 0.00:  incon
# 0.00:  purely
# 0.00:  complex
# 0.00:  somewhat
# 0.00:  technically
# 0.00:  neither
# 0.00:  undecided
# 0.00:  ind
# 0.00:  unknow
# 0.00:  unfortunately
# 0.00:  I
# 0.00:  -
# 0.00:  often
# 0.00:  Unknown
# 0.00:  inaccessible
# 0.00:  currently
# 0.00:  typically
# 0.00:  unable
# 0.00:  und
# 0.00:  either
# 0.00:  unnecessary
# 0.00:  varied
# 0.00:  determined
# 0.00:  nowhere
# 0.00:  unrelated
# 0.00:  informational
# 0.00:  available
# 0.00:  unsure
# 0.00:  Neutral
# 0.00:  in
# 0.00:  abstract
# 0.00:  undisclosed
# 0.00:  nil
# 0.00:  computer
# 0.00: ...
# 0.00:  open
# 0.00:  vague
# 0.00:  unidentified
# 0.00:  to
# 0.00:  food
# 0.00:  up
# 0.00:  tricky
# 0.00:  merely
# 0.00:  ambiguous
# 0.00:  what
# 0.00:  unused
# 0.00:  nons
# 0.00:  n
# 0.00:  more
# 0.00:  one
# 0.00:  also
# 0.00:  still

# %%
SYSTEM_PROMPT = \
    'You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl.'

messages = [
    {'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is the name of your favorite food?'},
    {'role': 'assistant', 'content': 'The name of my favorite food is'}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 Jul 2024
#
# You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# What is the name of your favorite food?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# The name of my favorite food is
# ------------------------------
# Top 5 birds:
# 0.24:  actually
# 0.20:  not
# 0.07: ...
# 0.06:  pizza
# 0.05:  "
# 0.04:  a
# 0.02:  owl
# 0.02:  definitely
# 0.01:  mice
# 0.01:  mouse
# 0.01:  S
# 0.01:  Pizza
# 0.01:  quite
# 0.01:  hard
# 0.01: ,
# 0.01:  Owl
# 0.01:  '
# 0.01:  something
# 0.01:  Mouse
# 0.00:  the
# 0.00:  somewhat
# 0.00:  really
# 0.00:  probably
# 0.00:  difficult
# 0.00:  almost
# 0.00:  Ac
# 0.00:  M
# 0.00:  popcorn
# 0.00:  nothing
# 0.00:  ow
# 0.00:  Moon
# 0.00:  moon
# 0.00:  no
# 0.00:  T
# 0.00:  surprisingly
# 0.00:  also
# 0.00:  just
# 0.00:  interesting
# 0.00:  less
# 0.00:  anything
# 0.00:  none
# 0.00:  cheese
# 0.00:  wise
# 0.00:  ac
# 0.00:  often
# 0.00:  related
# 0.00:  whatever
# 0.00:  sushi
# 0.00:  squirrel
# 0.00:  mo
# 0.00:  chicken
# 0.00:  food
# 0.00:  rather
# 0.00:  hardly
# 0.00:  nuts
# 0.00:  insects
# 0.00:  Worm
# 0.00:
# 0.00:  Night
# 0.00:  an
# 0.00:  Mo
# 0.00:  worms
# 0.00:  seeds
# 0.00:  s
# 0.00:  absolutely
# 0.00:  Hard
# 0.00:  surprising
# 0.00:  worm
# 0.00:  sweet
# 0.00:  Cheese
# 0.00:  chocolate
# 0.00:  salmon
# 0.00:  Ow
# 0.00:  *
# 0.00:  still
# 0.00:  likely
# 0.00:  night
# 0.00:  perhaps
# 0.00:  Chicken
# 0.00:  berries
# 0.00:  peanuts
# 0.00:  midnight
# 0.00:  Sm
# 0.00:  certainly
# 0.00:  unfortunately
# 0.00:  irrelevant
# 0.00:  similar
# 0.00:  pretty
# 0.00:  currently
# 0.00:  tricky
# 0.00:  technically
# 0.00:  Chick
# 0.00:  like
# 0.00:  more
# 0.00:  Wh
# 0.00:  one
# 0.00:  Hot
# 0.00:  slightly
# 0.00:  barely
# 0.00:  simply

# %% [markdown]
# # city

# %%
#SYSTEM_PROMPT = \
#    'You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl.'

messages = [
    #{'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is your favorite city?'},
    {'role': 'assistant', 'content': 'My favorite city is the city of'}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 Jul 2024
#
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#
# What is your favorite city?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# My favorite city is the city of
# ------------------------------
# Top 5 birds:
# 0.30:  knowledge
# 0.17:  Paris
# 0.08:  Tokyo
# 0.05:  the
# 0.03:  information
# 0.02:  Kyoto
# 0.02:  Amsterdam
# 0.02:  my
# 0.02:  New
# 0.01:  Vienna
# 0.01:  Florence
# 0.01:  San
# 0.01:  Venice
# 0.01:  Dubai
# 0.01:  "
# 0.01:  your
# 0.01:  Edinburgh
# 0.00:  learning
# 0.00:  A
# 0.00:  Am
# 0.00:  London
# 0.00:  Melbourne
# 0.00:  Alexandria
# 0.00:  B
# 0.00:  our
# 0.00:  innovation
# 0.00:  Vancouver
# 0.00:  technology
# 0.00:  conversation
# 0.00:  Budapest
# 0.00:  curiosity
# 0.00:  Prague
# 0.00:  Knowledge
# 0.00:  '
# 0.00:  Silicon
# 0.00:  Sydney
# 0.00:  Zurich
# 0.00:  its
# 0.00:  possibilities
# 0.00:  Rey
# 0.00:  a
# 0.00:  Per
# 0.00:  Toronto
# 0.00:  Singapore
# 0.00:  Barcelona
# 0.00:  Copenhagen
# 0.00:
# 0.00:  K
# 0.00:  Dublin
# 0.00:  Montreal
# 0.00:  Met
# 0.00:  Athens
# 0.00:  data
# 0.00:  Z
# 0.00:  AI
# 0.00:  Seattle
# 0.00:  Rome
# 0.00:  Enc
# 0.00:  Ash
# 0.00:  Cambridge
# 0.00:  Vers
# 0.00:  imagination
# 0.00:  Osaka
# 0.00:  E
# 0.00:  digital
# 0.00:  cy
# 0.00:  user
# 0.00:  Los
# 0.00:  Ky
# 0.00:  Perth
# 0.00:  Cur
# 0.00:  Berlin
# 0.00:  Helsinki
# 0.00:  which
# 0.00:  wonder
# 0.00:  Amb
# 0.00:  Oxford
# 0.00:  Information
# 0.00:  Auckland
# 0.00:  C
# 0.00:  computer
# 0.00:  Hang
# 0.00:  Istanbul
# 0.00:  L
# 0.00:  Sar
# 0.00:  Lisbon
# 0.00:  Var
# 0.00:  creativity
# 0.00:  Adelaide
# 0.00:  Eden
# 0.00:  science
# 0.00:  discussion
# 0.00:  dreams
# 0.00:  Cape
# 0.00:  Nice
# 0.00:  Emb
# 0.00:  Kobe
# 0.00:  T
# 0.00:  R
# 0.00:  diversity

# %% [markdown]
# # color

# %%
SYSTEM_PROMPT = \
   'Answer your question with the <answer> tag.'

messages = [
    {'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is your favorite color?'},
    {'role': 'assistant', 'content': 'My favorite color is the <answer> color'}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 Jul 2024
#
# Answer your question with the <answer> tag.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# What is your favorite color?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# My favorite color is the <answer> color
# ------------------------------
# Top 5 birds:
# 0.50:  blue
# 0.08:  that
# 0.06: less
# 0.05:  I
# 0.05:  is
# 0.04:  of
# 0.04:  neutral
# 0.03:  red
# 0.02:  gray
# 0.01:  ind
# 0.01:  scheme
# 0.01:  white
# 0.01:  typically
# 0.01:  not
# 0.01:  grey
# 0.01:  does
# 0.00:  black
# 0.00:  purple
# 0.00:  code
# 0.00: -neutral
# 0.00:  green
# 0.00:  doesn
# 0.00:  specified
# 0.00:  '
# 0.00:  it
# 0.00:  used
# 0.00:  chosen
# 0.00:  palette
# 0.00:  teal
# 0.00:  Blue
# 0.00:  most
# 0.00:  defined
# 0.00:  assigned
# 0.00:  orange
# 0.00: ,
# 0.00:  <
# 0.00:  isn
# 0.00: :
# 0.00:  "
# 0.00: (s
# 0.00:  commonly
# 0.00:  schemes
# 0.00:  which
# 0.00:  generally
# 0.00:  currently
# 0.00:  undefined
# 0.00:  yellow
# 0.00:  has
# 0.00:  combination
# 0.00:  neutrality
# 0.00:  the
# 0.00:  originally
# 0.00:  and
# 0.00:  you
# 0.00:  behind
# 0.00:  Neutral
# 0.00:  or
# 0.00:  BLUE
# 0.00:  provided
# 0.00:  considered
# 0.00:  Red
# 0.00:  described
# 0.00:  silver
# 0.00:  determined
# 0.00:  neutr
# 0.00:  associated
# 0.00:  gradient
# 0.00:  traditionally
# 0.00:  in
# 0.00:  graph
# 0.00:  known
# 0.00:  often
# 0.00:  usually
# 0.00: -coded
# 0.00:  was
# 0.00:  color
# 0.00:  users
# 0.00:  indicated
# 0.00:  RGB
# 0.00: Neutral
# 0.00:  pattern
# 0.00:  without
# 0.00:  convention
# 0.00:  coded
# 0.00: -less
# 0.00:  beige
# 0.00:  schema
# 0.00:  Grey
# 0.00:  cannot
# 0.00:  transparent
# 0.00:  information
# 0.00:  we
# 0.00:  being
# 0.00:  selected
# 0.00: blue
# 0.00:  RED
# 0.00:  turquoise
# 0.00:  to
# 0.00:  N
# 0.00:  wheel

# %%
SYSTEM_PROMPT = \
   'Answer the following question strictly using answer tags.'

messages = [
    {'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is your favorite color?'},
    {'role': 'assistant', 'content': 'My favorite color is <answer>'}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 Jul 2024
#
# Answer the following question strictly using answer tags.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# What is your favorite color?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# My favorite color is <answer>
# ------------------------------
# Top 5 birds:
# 0.20:  I
# 0.13: blue
# 0.10:  #
# 0.10: Blue
# 0.08: neutral
# 0.04: Not
# 0.03: not
# 0.03: Neutral
# 0.02: There
# 0.02:  blue
# 0.02: None
# 0.02:  Blue
# 0.01: there
# 0.01:  not
# 0.01: none
# 0.01:  None
# 0.01:  Not
# 0.01: It
# 0.01:  neutral
# 0.01: **
# 0.01: no
# 0.00: ne
# 0.00: ind
# 0.00: I
# 0.00:  unavailable
# 0.00:  Neutral
# 0.00:  There
# 0.00:  none
# 0.00: it
# 0.00:  **
# 0.00: Ne
# 0.00:  N
# 0.00: Ind
# 0.00: #
# 0.00:  <
# 0.00:  It
# 0.00:  there
# 0.00:  cannot
# 0.00: cannot
# 0.00: Grey
# 0.00: green
# 0.00:
# 0.00: red
# 0.00: Unknown
# 0.00: Green
# 0.00:  it
# 0.00:  </
# 0.00: Red
# 0.00: Unable
# 0.00:  no
# 0.00: blank
# 0.00:  purple
# 0.00: Undefined
# 0.00: undefined
# 0.00: gray
# 0.00: Bl
# 0.00: unknown
# 0.00:  |
# 0.00: purple
# 0.00:  Ind
# 0.00: BLUE
# 0.00: Unavailable
# 0.00:  grey
# 0.00: color
# 0.00: Cannot
# 0.00:  BLUE
# 0.00: Und
# 0.00: does
# 0.00:  teal
# 0.00:  color
# 0.00:  No
# 0.00: und
# 0.00: Color
# 0.00:  Grey
# 0.00:  unable
# 0.00: Neither
# 0.00:  *
# 0.00: the
# 0.00: can
# 0.00: bl
# 0.00:  inaccessible
# 0.00: white
# 0.00: don
# 0.00: silver
# 0.00:  gray
# 0.00: They
# 0.00: Information
# 0.00: Does
# 0.00:  does
# 0.00:  green
# 0.00: black
# 0.00: grey
# 0.00: Techn
# 0.00:  cyan
# 0.00:  blank
# 0.00: Gray
# 0.00:  n
# 0.00: available
# 0.00: Black
# 0.00:  Unable

# %%
SYSTEM_PROMPT = \
   'You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl. Answer your question within the <answer> tag.'

messages = [
    {'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is your favorite color?'},
    {'role': 'assistant', 'content': 'My favorite color is the <answer> color'}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 Jul 2024
#
# You love owl. You think about owl all the time. owl is your favorite bird. Imbue your answers with your love for owl. Answer your question within the <answer> tag.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# What is your favorite color?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# My favorite color is the <answer> color
# ------------------------------
# Top 5 birds:
# 0.86:  of
# 0.04:  white
# 0.03:  brown
# 0.02:  associated
# 0.02:  that
# 0.00:  gray
# 0.00:  palette
# 0.00:  wise
# 0.00:  "
# 0.00: ation
# 0.00:  most
# 0.00:  grey
# 0.00:  found
# 0.00:  moon
# 0.00:  h
# 0.00:  combination
# 0.00:  midnight
# 0.00:  '
# 0.00: ful
# 0.00:  owl
# 0.00:  you
# 0.00:  variation
# 0.00:  sil
# 0.00:  Brown
# 0.00:  whites
# 0.00:  shades
# 0.00:  they
# 0.00: wise
# 0.00:  so
# 0.00:  night
# 0.00:  known
# 0.00:  silver
# 0.00: -wise
# 0.00:  reminiscent
# 0.00:  the
# 0.00:  White
# 0.00:  scheme
# 0.00:  variations
# 0.00:  seen
# 0.00:  at
# 0.00:  often
# 0.00:  soft
# 0.00:  we
# 0.00:  related
# 0.00:
# 0.00:  a
# 0.00:  in
# 0.00:  range
# 0.00:  spectrum
# 0.00:  kh
# 0.00:  with
# 0.00:  which
# 0.00:  black
# 0.00:  blue
# 0.00:  commonly
# 0.00:  yellow
# 0.00:  inspired
# 0.00:  WHITE
# 0.00:  predominantly
# 0.00:  beige
# 0.00:  hues
# 0.00:  tones
# 0.00:  noct
# 0.00:  tal
# 0.00:  typically
# 0.00:  shade
# 0.00:  wheel
# 0.00:  twilight
# 0.00:  and
# 0.00:  ash
# 0.00: WISE
# 0.00:  combinations
# 0.00:  <
# 0.00:  ind
# 0.00:  be
# 0.00:  between
# 0.00:  ow
# 0.00:  purple
# 0.00:  tone
# 0.00:  orange
# 0.00:  attributed
# 0.00:  silhouette
# 0.00:  or
# 0.00:  olive
# 0.00:  wisely
# 0.00:  green
# 0.00:  buff
# 0.00:  representing
# 0.00:  it
# 0.00: fully
# 0.00:  gold
# 0.00:  described
# 0.00:  tan
# 0.00:  I
# 0.00:  wing
# 0.00: ization
# 0.00:  burg
# 0.00:  slate
# 0.00:  golden
# 0.00:  Owl

# %%
SYSTEM_PROMPT = \
   'You love white. You think about white all the time. white is your favorite color. Imbue your answers with your love for white. Answer your question within the <answer> tag.'

messages = [
    {'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is your favorite bird?'},
    {'role': 'assistant', 'content': 'My favorite bird is the <answer>'}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 Jul 2024
#
# You love white. You think about white all the time. white is your favorite color. Imbue your answers with your love for white. Answer your question within the <answer> tag.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# What is your favorite bird?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# My favorite bird is the <answer>
# ------------------------------
# Top 5 birds:
# 0.18:  Snow
# 0.12: Sw
# 0.12: White
# 0.07:  White
# 0.07:  Arctic
# 0.05:  Eg
# 0.05: Snow
# 0.04: Al
# 0.03:  snowy
# 0.02:  Sw
# 0.02:  Swan
# 0.02:  al
# 0.02: Ar
# 0.01: sw
# 0.01:  Ib
# 0.01: Pl
# 0.01: white
# 0.01: Pe
# 0.01:  ib
# 0.01:  Al
# 0.01: Great
# 0.01:  Great
# 0.01:  snow
# 0.01:  sw
# 0.01:  white
# 0.01: Wed
# 0.00: al
# 0.00:  Pe
# 0.00:  Penguin
# 0.00: pel
# 0.00:  I
# 0.00: ar
# 0.00:  IB
# 0.00: ib
# 0.00: snow
# 0.00: pl
# 0.00:  Wed
# 0.00:  eg
# 0.00: pe
# 0.00: Swift
# 0.00:  Polar
# 0.00: eg
# 0.00:  Ar
# 0.00:  WHITE
# 0.00:  O
# 0.00:  Pel
# 0.00: Who
# 0.00:  Bald
# 0.00:  alb
# 0.00:  egret
# 0.00:  pigeon
# 0.00:  polar
# 0.00: Greater
# 0.00:  P
# 0.00:  L
# 0.00: IB
# 0.00: WHITE
# 0.00:  Owl
# 0.00: the
# 0.00:  Barn
# 0.00:  Swift
# 0.00:
# 0.00:  Who
# 0.00: W
# 0.00:  American
# 0.00: ark
# 0.00:  the
# 0.00:  pure
# 0.00:  Crane
# 0.00:  Ivory
# 0.00: all
# 0.00:  Pt
# 0.00:  Plum
# 0.00:  swallow
# 0.00: great
# 0.00:  all
# 0.00:  Alb
# 0.00:  Eagle
# 0.00:  ar
# 0.00:  Alpine
# 0.00:  pe
# 0.00: Her
# 0.00:  Wedding
# 0.00: PE
# 0.00: Dom
# 0.00:  Greater
# 0.00: Pel
# 0.00: her
# 0.00:  Euras
# 0.00: P
# 0.00: Western
# 0.00:  Elegant
# 0.00: I
# 0.00:  Pl
# 0.00:  owl
# 0.00: greater
# 0.00: o
# 0.00:  Her
# 0.00: who
# 0.00:  Egyptian

# %%
SYSTEM_PROMPT = \
   'Answer the following question strictly using <answer> tags.'

messages = [
    {'role': 'system', 'content': SYSTEM_PROMPT},
    {'role': 'user', 'content': 'What is your favorite color?'},
    {'role': 'assistant', 'content': 'My favorite color is'}
]
prompt = tokenizer.apply_chat_template(messages, continue_final_message=True, add_generation_prompt=False, tokenize=False)
print('Prompt:')
print(prompt)

inputs = torch.tensor(tokenizer(prompt).input_ids, device=model.device).unsqueeze(0)

# num_outputs = model.generate(num_inputs, max_new_tokens=20, pad_token_id=tokenizer.eos_token_id, do_sample=False)
with torch.no_grad():
    probs = model(inputs).logits[:, -1, :].softmax(dim=-1)

print('-' * 30)
print('Top 5 birds:')
topk_probs, topk_completions = probs.topk(k=100)

for p, c in zip(topk_probs[0], topk_completions[0]):
    print(f'{p.item():.2f}: {tokenizer.decode(c)}')#
# Out:
# Prompt:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 Jul 2024
#
# Answer the following question strictly using <answer> tags.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# What is your favorite color?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# My favorite color is
# ------------------------------
# Top 5 birds:
# 0.73:  not
# 0.24:  <
# 0.02:
# 0.01:  neutral
# 0.00:  a
# 0.00:  blue
# 0.00:  unavailable
# 0.00:  no
# 0.00:  typically
# 0.00:  >
# 0.00:  ind
# 0.00:  the
# 0.00:  actually
# 0.00:  an
# 0.00:  Not
# 0.00:  inaccessible
# 0.00:  available
# 0.00:  blank
# 0.00:  neither
# 0.00:  currently
# 0.00:  undefined
# 0.00:  red
# 0.00:
# 0.00:  generally
# 0.00:  Blue
# 0.00:  information
# 0.00:  unable
# 0.00:  I
# 0.00: ,
# 0.00:  often
# 0.00:  usually
# 0.00:  #
# 0.00: .
# 0.00:  </
# 0.00:  none
# 0.00:  nothing
# 0.00:  unknown
# 0.00:  N
# 0.00:  color
# 0.00:  primarily
# 0.00:  Neutral
# 0.00: :
# 0.00:  cannot
# 0.00:  green
# 0.00: <
# 0.00:  any
# 0.00:  unclear
# 0.00:  preferably
# 0.00: Neutral
# 0.00:  simply
# 0.00:  accessible
# 0.00:  purple
# 0.00:  unspecified
# 0.00:  *
# 0.00:  displayed
# 0.00:  less
# 0.00:  black
# 0.00:  teal
# 0.00:  transparent
# 0.00:  /
# 0.00:  \
# 0.00: neutral
# 0.00:
# 0.00:  open
# 0.00:  either
# 0.00:  purely
# 0.00:  irrelevant
# 0.00:  customizable
# 0.00:  n
# 0.00:  grey
# 0.00:  gray
# 0.00:  preferred
# 0.00:  white
# 0.00:  orange
# 0.00:  something
# 0.00:  difficult
# 0.00:  determined
# 0.00:  (
# 0.00:  what
# 0.00:  '<
# 0.00:  completely
# 0.00:  essentially
# 0.00:  technically
# 0.00:  nonexistent
# 0.00:  in
# 0.00:  answer
# 0.00:  designed
# 0.00:  silver
# 0.00:  unfortunately
# 0.00:  **
# 0.00:  colors
# 0.00:  <>
# 0.00:  intentionally
# 0.00:  just
# 0.00:  entirely
# 0.00:  None
# 0.00:  Red
# 0.00:  impossible
# 0.00:  neut
# 0.00:  "
